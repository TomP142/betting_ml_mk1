# %% [markdown]
# # NBA Data Exploration & Model Evaluation
#
# This notebook navigates the data and models generated by the pipeline.

# %%
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from src.feature_engineer import FeatureEngineer

# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
df = pd.read_parquet('../data/processed/processed_features.parquet')
print(f"Loaded {len(df)} rows")
df.head()

# %% [markdown]
# ## Feature Correlations

# %%
targets = ['PTS', 'REB', 'AST']
corr = df[targets + [c for c in df.columns if 'ROLL' in c]].corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=False, cmap='coolwarm')

# %% [markdown]
# ## Model Performance

# %%
model_pts = joblib.load('../data/models/xgb_PTS.pkl')
print("Points Model Loaded")
# Feature Importance
xgb.plot_importance(model_pts, max_num_features=10)
